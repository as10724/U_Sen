# %% [markdown]
# ## NYU-CUSP : Urban Sensing
#
# # Assignment #3
#
# ### Author: Avikal Somvanshi

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %% [markdown]
# ## Evening Levels (9:29-10:29 PM)

# %%
#loading raw noise data 
sound1 = pd.read_csv('as10724_rms.csv')
sound1.describe()
# Out:
#          Unnamed: 0         Time2           RMS
# count  77521.000000  77521.000000  77521.000000
# mean   38760.000000   1800.010884      0.108521
# std    22378.529446   1039.256878      0.054798
# min        0.000000      0.000000      0.007816
# 25%    19380.000000    900.005442      0.069087
# 50%    38760.000000   1800.010884      0.099649
# 75%    58140.000000   2700.016327      0.138152
# max    77520.000000   3600.021769      0.571324

# %%
#Visiualizing the raw data
plt.figure(figsize=(18,8))
plt.plot(sound1['Time2'], sound1['RMS'], 'k', alpha=.8)
plt.title('Noise in RMS', size=24)
plt.xlabel("Time in seconds", size=14)
plt.ylabel("RMS", size=14)

# %%
#loading aggregated data in decibels 
sound2 = pd.read_csv('as10724_decibel.csv')
sound2.describe()
# Out:
#         Unnamed: 0          RMS     decibels
# count  3603.000000  3603.000000  3603.000000
# mean   1801.000000     0.108519    22.309999
# std    1040.240837     0.037996     3.142180
# min       0.000000     0.018213     7.347595
# 25%     900.500000     0.082005    20.416833
# 50%    1801.000000     0.104068    22.486391
# 75%    2701.500000     0.131006    24.485830
# max    3602.000000     0.368486    33.468446

# %%
#setting datetime index
sound2.index = pd.to_datetime(sound2.Time)

# %%
#Visiualizing the raw data
plt.figure(figsize=(18,8))
plt.plot(sound2.index, sound2['decibels'], 'k', alpha=.8)
plt.plot([sound2.index[0], sound2.index[-1]], [np.mean(sound2.decibels), np.mean(sound2.decibels)], 'r', label = 'Mean')
plt.title('Noise in decibels', size=24)
plt.xlabel("Time", size=14)
plt.ylabel("decibels", size=14)
plt.legend()

# %% [markdown]
# ## Night Levels (2:29-3:29 AM)

# %%
#loading raw noise data 
sound12 = pd.read_csv('as10724_rms2.csv')
sound12.describe()
# Out:
#          Unnamed: 0         Time2           RMS
# count  77521.000000  77521.000000  77521.000000
# mean   38760.000000   1800.010884      0.019244
# std    22378.529446   1039.256878      0.017502
# min        0.000000      0.000000      0.004735
# 25%    19380.000000    900.005442      0.008525
# 50%    38760.000000   1800.010884      0.012687
# 75%    58140.000000   2700.016327      0.023789
# max    77520.000000   3600.021769      0.335201

# %%
#Visiualizing the raw data
plt.figure(figsize=(18,8))
plt.plot(sound12['Time2'], sound12['RMS'], 'k', alpha=.8)
plt.title('Noise in RMS', size=24)
plt.xlabel("Time in seconds", size=14)
plt.ylabel("RMS", size=14)

# %%
#loading aggregated data in decibels 
sound22 = pd.read_csv('as10724_decibel2.csv')
sound22.describe()
# Out:
#         Unnamed: 0          RMS     decibels
# count  3602.000000  3602.000000  3602.000000
# mean   1800.500000     0.019277    10.957521
# std    1039.952162     0.012173     4.438800
# min       0.000000     0.005975     2.021014
# 25%     900.250000     0.011354     7.597471
# 50%    1800.500000     0.015962    10.556190
# 75%    2700.750000     0.023619    13.959313
# max    3601.000000     0.136811    29.216710

# %%
#setting datetime index
sound22.index = pd.to_datetime(sound22.Time)

# %%
#Visiualizing the raw data
plt.figure(figsize=(18,8))
plt.plot(sound22.index, sound22['decibels'], 'k', alpha=.8)
plt.plot([sound22.index[0], sound22.index[-1]], [np.mean(sound22.decibels), np.mean(sound22.decibels)], 'r', label = 'Mean')
plt.title('Noise in decibels', size=24)
plt.xlabel("Time", size=14)
plt.ylabel("decibels", size=14)
plt.legend()

# %% [markdown]
# ## Morning Levels (7:26-8:26 AM)

# %%
#loading raw noise data 
sound13 = pd.read_csv('as10724_rms3.csv')
sound13.describe()
# Out:
#          Unnamed: 0         Time2           RMS
# count  77521.000000  77521.000000  77521.000000
# mean   38760.000000   1800.010884      0.022408
# std    22378.529446   1039.256878      0.044885
# min        0.000000      0.000000      0.001344
# 25%    19380.000000    900.005442      0.006658
# 50%    38760.000000   1800.010884      0.012292
# 75%    58140.000000   2700.016327      0.023261
# max    77520.000000   3600.021769      0.737096

# %%
#Visiualizing the raw data
plt.figure(figsize=(18,8))
plt.plot(sound13['Time2'], sound13['RMS'], 'k', alpha=.8)
plt.title('Noise in RMS', size=24)
plt.xlabel("Time in seconds", size=14)
plt.ylabel("RMS", size=14)

# %%
#loading aggregated data in decibels 
sound23 = pd.read_csv('as10724_decibel3.csv')
sound23.describe()
# Out:
#         Unnamed: 0          RMS     decibels
# count  3602.000000  3602.000000  3602.000000
# mean   1800.500000     0.022397    20.494196
# std    1039.952162     0.036872     7.233354
# min       0.000000     0.002405     5.055445
# 25%     900.250000     0.008036    15.532631
# 50%    1800.500000     0.012883    19.632236
# 75%    2700.750000     0.022925    24.638253
# max    3601.000000     0.410314    49.694449

# %%
#setting datetime index
sound23.index = pd.to_datetime(sound23.Time)

# %%
#Visiualizing the raw data
plt.figure(figsize=(18,8))
plt.plot(sound23.index, sound23['decibels'], 'k', alpha=.8)
plt.plot([sound23.index[0], sound23.index[-1]], [np.mean(sound23.decibels), np.mean(sound23.decibels)], 'r', label = 'Mean')
plt.title('Noise in decibels', size=24)
plt.xlabel("Time", size=14)
plt.ylabel("decibels", size=14)
plt.legend()

# %% [markdown]
# ## Comparitive Levels

# %%
#Visiualizing the raw data
plt.figure(figsize=(18,8))
plt.plot(sound2['Unnamed: 0'], sound2['decibels'], 'r', alpha=.5, label = 'Evening levels')
plt.plot(sound23['Unnamed: 0'], sound23['decibels'], 'b', alpha=.5, label = 'Morning levels')
plt.plot(sound22['Unnamed: 0'], sound22['decibels'], 'g', alpha=.5, label = 'Night levels')
plt.plot([sound2['Unnamed: 0'][0], sound2['Unnamed: 0'][-1]], [np.mean(sound2.decibels), np.mean(sound2.decibels)], 'r', label = 'Evening Mean')
plt.plot([sound22['Unnamed: 0'][0], sound22['Unnamed: 0'][-1]], [np.mean(sound22.decibels), np.mean(sound22.decibels)], 'g', label = 'Night Mean')
plt.plot([sound23['Unnamed: 0'][0], sound23['Unnamed: 0'][-1]], [np.mean(sound23.decibels), np.mean(sound23.decibels)], 'b', label = 'Morning Mean')
plt.title('Noise in decibels', size=24)
plt.xlabel("Time", size=14)
plt.ylabel("decibels", size=14)
plt.legend()
