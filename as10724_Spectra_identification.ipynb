# %% [markdown]
# # Urban Sensing
#
# ## Spectra Identification Assignment
#
# ### Author: Avikal Somvanshi (as10724)

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import scipy.ndimage as nd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.signal import find_peaks_cwt

from scipy import signal, interpolate

# %%
spectra = pd.read_csv('data/Unknown_sample_spectra.csv')

# %%
def scale(x, in_min, in_max, out_min, out_max):
    return (x - in_min) * (out_max - out_min) / (in_max - in_min) + out_min

# %%
fig, ax = plt.subplots(1, figsize=(12,3))

x = spectra['Wavelength']

plt.plot(x, spectra['Average'], color='black')
plt.plot(x, spectra['Red'], color='red', lw=0.3)
plt.plot(x, spectra['Green'], color='green', lw=0.3)
plt.plot(x, spectra['Blue'], color='blue', lw=0.3)
plt.title("Unknown Spectra")
plt.xlabel('Wavelength')
plt.ylabel('Intensity')

# %%
avg_spectra = scale(spectra['Average'], spectra['Average'].min(), spectra['Average'].max(), 0, 255)

# %% [markdown]
# ## Checking with Argon

# %%
# The txt file contains: wavelength and intensity
# the wavelength is in microns not nanometers
fname = 'data/argon.txt'
Ar = np.loadtxt(fname)

# rescale intensities to values between 0-255.  This is scale of 
# the captured image
Ar[:,1] = scale(Ar[:,1], Ar[:,1].min(), Ar[:,1].max(), 0 , 255)

# convert to nanometers
Ar[:,0] = Ar[:,0] / 10

# %%
# plot
fig, ax = plt.subplots(1, figsize=(12,3))
plt.scatter(Ar[:,0], Ar[:,1], color='red')
plt.plot(x, spectra['Average'], color='black')
plt.title('Comparison with known Spectra with Argon')
plt.xlabel('Wavelength')
plt.ylabel('Intensity')

# %% [markdown]
# #### Doesnt seem similar...must be something else...

# %% [markdown]
# ## Checking with Oxygen

# %%
# The txt file contains: wavelength and intensity
# the wavelength is in microns not nanometers
fname = 'data/oxygen.txt'
O2 = np.loadtxt(fname)

# rescale intensities to values between 0-255.  This is scale of 
# the captured image
O2[:,1] = scale(O2[:,1], O2[:,1].min(), O2[:,1].max(), 0 , 255)

# convert to nanometers
O2[:,0] = O2[:,0] / 10

# %%
# plot
fig, ax = plt.subplots(1, figsize=(12,3))
plt.scatter(O2[:,0], O2[:,1], color='red')
plt.plot(x, spectra['Average'], color='black')
plt.title('Comparison with known Spectra with Oxgyen')
plt.xlabel('Wavelength')
plt.ylabel('Intensity')

# %% [markdown]
# #### Doesnt seem similar...must be something else...

# %% [markdown]
# ## Checking with Hydrogen

# %%
# The txt file contains: wavelength and intensity
# the wavelength is in microns not nanometers
fname = 'data/hydrogen.txt'
Hr = np.loadtxt(fname)

# rescale intensities to values between 0-255.  This is scale of 
# the captured image
Hr[:,1] = scale(Hr[:,1], Hr[:,1].min(), Hr[:,1].max(), 0 , 255)

# convert to nanometers
Hr[:,0] = Hr[:,0] / 10

# %%
# plot
fig, ax = plt.subplots(1, figsize=(12,3))
plt.scatter(Hr[:,0], Hr[:,1], color='red')
plt.plot(x, spectra['Average'], color='black')
plt.title('Comparison with known Spectra with Hydrogen')
plt.xlabel('Wavelength')
plt.ylabel('Intensity')

# %% [markdown]
# #### Doesnt seem similar...must be something else...

# %% [markdown]
# ## Checking with Barium

# %%
# The txt file contains: wavelength and intensity
# the wavelength is in microns not nanometers
fname = 'data/barium.txt'
Br = np.loadtxt(fname)

# rescale intensities to values between 0-255.  This is scale of 
# the captured image
Br[:,1] = scale(Br[:,1], Br[:,1].min(), Br[:,1].max(), 0 , 255)

# convert to nanometers
Br[:,0] = Br[:,0] / 10

# %%
# plot
fig, ax = plt.subplots(1, figsize=(12,3))
plt.scatter(Br[:,0], Br[:,1], color='red')
plt.plot(x, spectra['Average'], color='black')
plt.title('Comparison with known Spectra with Barium')
plt.xlabel('Wavelength')
plt.ylabel('Intensity')

# %% [markdown]
# #### Doesnt seem similar...must be something else...

# %% [markdown]
# ## Checking with Mercury

# %%
# The txt file contains: wavelength and intensity
# the wavelength is in microns not nanometers
fname = 'data/mercury.txt'
Hg = np.loadtxt(fname)

# rescale intensities to values between 0-255.  This is scale of 
# the captured image
Hg[:,1] = scale(Hg[:,1], Hg[:,1].min(), Hg[:,1].max(), 0 , 255)

# convert to nanometers
Hg[:,0] = Hg[:,0] / 10

# %%
# plot
fig, ax = plt.subplots(1, figsize=(12,3))
plt.scatter(Hg[:,0], Hg[:,1], color='red')
plt.plot(x, spectra['Average'], color='black')
plt.title('Comparison with known Spectra with Mercury')
plt.xlabel('Wavelength')
plt.ylabel('Intensity')

# %% [markdown]
# #### Doesnt seem similar...must be something else...

# %% [markdown]
# ## Checking with Sodium

# %%
# The txt file contains: wavelength and intensity
# the wavelength is in microns not nanometers
fname = 'data/sodium.txt'
Na = np.loadtxt(fname)

# rescale intensities to values between 0-255.  This is scale of 
# the captured image
Na[:,1] = scale(Na[:,1], Na[:,1].min(), Na[:,1].max(), 0 , 255)

# convert to nanometers
Na[:,0] = Na[:,0] / 10

# %%
# plot
fig, ax = plt.subplots(1, figsize=(12,3))
plt.scatter(Na[:,0], Na[:,1], color='red')
plt.plot(x, spectra['Average'], color='black')
plt.title('Comparison with known Spectra with Sodium')
plt.xlabel('Wavelength')
plt.ylabel('Intensity')

# %% [markdown]
# #### Does seem similar...must be further explored...

# %%
# plot with red spectrum
fig, ax = plt.subplots(1, figsize=(12,3))
plt.scatter(Na[:,0], Na[:,1], color='red')
plt.plot(x, spectra['Red'], color='black')
plt.title('Comparison with known Spectra with Sodium')
plt.xlabel('Wavelength')
plt.ylabel('Intensity')
